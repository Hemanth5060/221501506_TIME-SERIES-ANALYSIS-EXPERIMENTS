# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime

# %%
# Load the dataset
file_path = r'C:\Users\heman\OneDrive\Desktop\dataset\global air pollution dataset.csv'  # Use raw string (r) to avoid escape characters
df = pd.read_csv(file_path)

# Display the first few rows of the dataset
print(df.head())
# Out:
#               Country              City  AQI Value AQI Category  CO AQI Value  \
# 0  Russian Federation        Praskoveya         51     Moderate             1
# 1              Brazil  Presidente Dutra         41         Good             1
# 2               Italy   Priolo Gargallo         66     Moderate             1
# 3              Poland         Przasnysz         34         Good             1
# 4              France          Punaauia         22         Good             0
#
#   CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 0            Good               36               Good              0
# 1            Good                5               Good              1
# 2            Good               39               Good              2
# 3            Good               34               Good              0
# 4            Good               22               Good              0
#
#   NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category
# ...

# %%
# Print the column names of the dataset to see what they are
print(df.columns)
# Out:
# Index(['Country', 'City', 'AQI Value', 'AQI Category', 'CO AQI Value',
#        'CO AQI Category', 'Ozone AQI Value', 'Ozone AQI Category',
#        'NO2 AQI Value', 'NO2 AQI Category', 'PM2.5 AQI Value',
#        'PM2.5 AQI Category'],
#       dtype='object')

# %%
# Remove any leading/trailing spaces from column names
df.columns = df.columns.str.strip()

# Inspect the cleaned column names again
print(df.columns)
# Out:
# Index(['Country', 'City', 'AQI Value', 'AQI Category', 'CO AQI Value',
#        'CO AQI Category', 'Ozone AQI Value', 'Ozone AQI Category',
#        'NO2 AQI Value', 'NO2 AQI Category', 'PM2.5 AQI Value',
#        'PM2.5 AQI Category'],
#       dtype='object')

# %%
# Load the dataset
import pandas as pd

file_path = r'C:\Users\heman\OneDrive\Desktop\dataset\global air pollution dataset.csv'  # Your dataset path
df = pd.read_csv(file_path)

# Print the column names
print("Columns:", df.columns)

# Display the first few rows to check the data structure
print(df.head())
# Out:
# Columns: Index(['Country', 'City', 'AQI Value', 'AQI Category', 'CO AQI Value',
#        'CO AQI Category', 'Ozone AQI Value', 'Ozone AQI Category',
#        'NO2 AQI Value', 'NO2 AQI Category', 'PM2.5 AQI Value',
#        'PM2.5 AQI Category'],
#       dtype='object')
#               Country              City  AQI Value AQI Category  CO AQI Value  \
# 0  Russian Federation        Praskoveya         51     Moderate             1
# 1              Brazil  Presidente Dutra         41         Good             1
# 2               Italy   Priolo Gargallo         66     Moderate             1
# 3              Poland         Przasnysz         34         Good             1
# 4              France          Punaauia         22         Good             0
#
#   CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 0            Good               36               Good              0
# 1            Good                5               Good              1
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = r'C:\Users\heman\OneDrive\Desktop\dataset\global air pollution dataset.csv'
df = pd.read_csv(file_path)

# Strip leading/trailing spaces from column names if any
df.columns = df.columns.str.strip()

# Check for missing values
print(df.isnull().sum())

# Separate numeric and categorical columns
numeric_cols = df.select_dtypes(include='number').columns
categorical_cols = df.select_dtypes(include='object').columns

# Fill missing numeric values with the mean
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# Fill missing categorical values with the mode (most frequent value)
df[categorical_cols] = df[categorical_cols].fillna(df[categorical_cols].mode().iloc[0])

# Check for missing values again
print(df.isnull().sum())

# Visualize the distribution of AQI values for PM2.5
plt.figure(figsize=(10, 6))
sns.histplot(df['PM2.5 AQI Value'], kde=True)
plt.title('Distribution of PM2.5 AQI Values')
plt.xlabel('PM2.5 AQI Value')
plt.ylabel('Frequency')
plt.show()

# Boxplot of AQI categories by pollutant type
plt.figure(figsize=(12, 6))
sns.boxplot(x='AQI Category', y='AQI Value', data=df)
plt.title('Boxplot of AQI Categories by Pollutant')
plt.show()
# Out:
# Country               427
# City                    1
# AQI Value               0
# AQI Category            0
# CO AQI Value            0
# CO AQI Category         0
# Ozone AQI Value         0
# Ozone AQI Category      0
# NO2 AQI Value           0
# NO2 AQI Category        0
# PM2.5 AQI Value         0
# PM2.5 AQI Category      0
# dtype: int64
# Country               0
# City                  0
# AQI Value             0
# AQI Category          0
# CO AQI Value          0
# CO AQI Category       0
# Ozone AQI Value       0
# Ozone AQI Category    0
# NO2 AQI Value         0
# NO2 AQI Category      0
# PM2.5 AQI Value       0
# PM2.5 AQI Category    0
# dtype: int64
